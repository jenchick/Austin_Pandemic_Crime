# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine, func
import psycopg2
from psycopg2 import OperationalError, errorcodes, errors
import numpy as np

# %%
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/postgres"
engine = create_engine(db_string)

# %%
covid_crime_df = pd.read_sql_table('complete_2020', engine)

# %%
covid_crime_df.head()
# Out:
#   zipcode  mar2020  apr2020  may2020  jun2020  jul2020  aug2020  sep2020  \
# 0   78704       62     1523     3098     5391    17394    24714    25147
# 1   78756       12      106      190      392     1742     2529     2465
# 2   78759       34      446      649     1413     7266    12513    12781
# 3   78723       19      576     2009     4303    14693    21775    21202
# 4   78759       34      446      649     1413     7266    12513    12781
#
#    oct2020  nov2020  dec2020  incident_number    offense_description  \
# 0    30246    36122    51696     2.020500e+10     ROBBERY BY ASSAULT
# 1     3161     4016     5891     2.020500e+10    THEFT FROM BUILDING
# 2    15712    18367    25876     2.020500e+10                  THEFT
# 3    25520    28927    36150     2.020213e+08             AUTO THEFT
# 4    15712    18367    25876     2.020313e+08  BURGLARY OF RESIDENCE
#
#   family_violence       date                 location_type  \
# 0               N 2020-01-01  STREETS / HWY / ROAD / ALLEY
# 1               N 2020-01-01              RESIDENCE / HOME
# 2               N 2020-01-01              RESIDENCE / HOME
# 3               N 2020-01-01         PARKING LOTS / GARAGE
# 4               N 2020-01-01              RESIDENCE / HOME
#
#   category_description
# 0              Robbery
# 1                Theft
# 2                Theft
# 3           Auto Theft
# 4             Burglary

# %%
# Check data types
covid_crime_df.dtypes
# Out:
# zipcode                         object
# mar2020                          int64
# apr2020                          int64
# may2020                          int64
# jun2020                          int64
# jul2020                          int64
# aug2020                          int64
# sep2020                          int64
# oct2020                          int64
# nov2020                          int64
# dec2020                          int64
# incident_number                float64
# offense_description             object
# family_violence                 object
# date                    datetime64[ns]
# location_type                   object
# category_description            object
# dtype: object

# %%
covid_crime_df["rates"] = covid_crime_df["mar2020"] + covid_crime_df["apr2020"] + covid_crime_df["may2020"] + covid_crime_df["jun2020"] + covid_crime_df["jul2020"] + covid_crime_df["aug2020"] + covid_crime_df["sep2020"] + covid_crime_df["oct2020"] + covid_crime_df["nov2020"] + covid_crime_df["dec2020"]

# %%
covid_crime_df.head()
# Out:
#   zipcode  mar2020  apr2020  may2020  jun2020  jul2020  aug2020  sep2020  \
# 0   78704       62     1523     3098     5391    17394    24714    25147
# 1   78756       12      106      190      392     1742     2529     2465
# 2   78759       34      446      649     1413     7266    12513    12781
# 3   78723       19      576     2009     4303    14693    21775    21202
# 4   78759       34      446      649     1413     7266    12513    12781
#
#    oct2020  nov2020  dec2020  incident_number    offense_description  \
# 0    30246    36122    51696     2.020500e+10     ROBBERY BY ASSAULT
# 1     3161     4016     5891     2.020500e+10    THEFT FROM BUILDING
# 2    15712    18367    25876     2.020500e+10                  THEFT
# 3    25520    28927    36150     2.020213e+08             AUTO THEFT
# 4    15712    18367    25876     2.020313e+08  BURGLARY OF RESIDENCE
#
#   family_violence       date                 location_type  \
# 0               N 2020-01-01  STREETS / HWY / ROAD / ALLEY
# 1               N 2020-01-01              RESIDENCE / HOME
# 2               N 2020-01-01              RESIDENCE / HOME
# 3               N 2020-01-01         PARKING LOTS / GARAGE
# 4               N 2020-01-01              RESIDENCE / HOME
#
#   category_description   rates
# 0              Robbery  195393
# 1                Theft   20504
# 2                Theft   95057
# 3           Auto Theft  155174
# 4             Burglary   95057

# %%
#Drop columns
covid_crime_df = covid_crime_df.drop(columns=['mar2020', 'apr2020', 'may2020', 'jun2020', 'jul2020', 'aug2020', 'sep2020', 'oct2020','nov2020', 'dec2020'], axis=1)

# %%
# Drop additional columns
covid_crime_df = covid_crime_df.drop(columns=['offense_description', 'family_violence', 'date', 'location_type', 'category_description'])

# %%
covid_crime_df
# Out:
#       zipcode  incident_number   rates
# 0       78704     2.020500e+10  195393
# 1       78756     2.020500e+10   20504
# 2       78759     2.020500e+10   95057
# 3       78723     2.020213e+08  155174
# 4       78759     2.020313e+08   95057
# ...       ...              ...     ...
# 40153   78644              NaN     513
# 40154   78634              NaN    1671
# 40155   78663              NaN      24
# 40156   78640              NaN    2108
# 40157   78628              NaN     150
#
# [40158 rows x 3 columns]

# %%
covid_crime_df.dropna()
# Out:
#       zipcode  incident_number   rates
# 0       78704     2.020500e+10  195393
# 1       78756     2.020500e+10   20504
# 2       78759     2.020500e+10   95057
# 3       78723     2.020213e+08  155174
# 4       78759     2.020313e+08   95057
# ...       ...              ...     ...
# 40148   78759     2.021207e+08   95057
# 40149   78701     2.020366e+10   56747
# 40150   78758     2.020366e+10  306412
# 40151   78759     2.020505e+10   95057
# 40152   78753     2.020505e+10  366997
#
# [40136 rows x 3 columns]

# %%
covid_crime_df = covid_crime_df.reset_index()

# %%
y = covid_crime_df['incident_number']
X = covid_crime_df.drop(columns= 'incident_number')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=75)

# %%
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
   intercept_scaling=1, max_iter=100, multi_class='warn', penalty='12',
   random_state=1, solver='lbfgs', tol=0.0001, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', penalty='12', random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# /Users/gabbiefechter/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['quoted_name', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yq/t1m8hmrs49qb30bck9s2wf6r0000gn/T/ipykernel_16121/3959894982.py in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     977     )
#     978
# --> 979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
#     981     check_consistent_length(X, y)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric)
#     992     else:
#     993         y = column_or_1d(y, warn=True)
# --> 994         _assert_all_finite(y)
#     995         _ensure_no_complex_data(y)
#     996     if y_numeric and y.dtype.kind == "O":
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})

# %%
accuracy_score(y_test, predictions)
