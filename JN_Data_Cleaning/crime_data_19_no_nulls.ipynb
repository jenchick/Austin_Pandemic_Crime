# %%
import pandas as pd
import numpy as np

# %%
cleaned_crime_2019 = pd.read_csv('clean_crime19.csv').replace(np.nan, 0)
cleaned_crime_2019
# Out:
#     zipcode  crime_jan2019  crime_feb2019  crime_mar2019  crime_apr2019  \
# 0     78728            0.0            0.0            0.0            0.0
# 1     78702          168.0          168.0          168.0          116.0
# 2     78756           22.0           22.0           22.0           21.0
# 3     78721           53.0           53.0           53.0           39.0
# 4     78754           32.0           32.0           32.0           24.0
# 5     78726           23.0           23.0           23.0           25.0
# 6     78759          116.0          116.0          116.0          137.0
# 7     78735           36.0           36.0           36.0           28.0
# 8     78742            4.0            4.0            4.0            3.0
# 9     78725            4.0            4.0            4.0            2.0
# 10    78652            0.0            0.0            0.0            0.0
# 11    78653            4.0            4.0            4.0            4.0
# ...

# %%
cleaned_crime_2019.to_csv('final_crime19.csv')
